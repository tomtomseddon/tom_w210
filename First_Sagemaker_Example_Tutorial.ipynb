# %%
from sagemaker import get_execution_role

role = get_execution_role()
bucket='sagemaker-w210-022118'

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json

# Load the dataset
urllib.request.urlretrieve("http://deeplearning.net/data/mnist/mnist.pkl.gz", "mnist.pkl.gz")
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 2.44 s, sys: 492 ms, total: 2.93 s
# Wall time: 4.07 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (2,10)


def show_digit(img, caption='', subplot=None):
    if subplot==None:
        _,(subplot)=plt.subplots(1,1)
    imgr=img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][30], 'This is a {}'.format(train_set[1][30]))

# %%
# %%time
from sagemaker.amazon.common import write_numpy_to_dense_tensor
import io
import boto3

data_key = 'kmeans_lowlevel_example/data'
data_location = 's3://{}/{}'.format(bucket, data_key)
print('training data will be uploaded to: {}'.format(data_location))

# Convert the training data into the format required by the SageMaker KMeans algorithm
buf = io.BytesIO()
write_numpy_to_dense_tensor(buf, train_set[0], train_set[1])
buf.seek(0)

boto3.resource('s3').Bucket(bucket).Object(data_key).upload_fileobj(buf)
# Out:
# training data will be uploaded to: s3://sagemaker-w210-022118/kmeans_lowlevel_example/data
# CPU times: user 23.1 s, sys: 752 ms, total: 23.9 s
# Wall time: 26.3 s

# %%
from sagemaker import KMeans

data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_example/output'.format(bucket)

print('training data will be uploaded to: {}'.format(data_location))
print('training artifacts will be uploaded to: {}'.format(output_location))

kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.8xlarge',
                output_path=output_location,
                k=10,
                data_location=data_location)
# Out:
# training data will be uploaded to: s3://sagemaker-w210-022118/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-w210-022118/kmeans_example/output
# INFO:sagemaker:Created S3 bucket: sagemaker-us-east-1-932794931219

# %%
# %%time

kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# INFO:sagemaker:Creating training-job with name: kmeans-2018-02-21-15-29-13-264
# .....................................................................
# Docker entrypoint called with argument(s): train
# [02/21/2018 15:34:55 INFO 140204977600320] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:34:55 INFO 140204977600320] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'mini_batch_size': u'500', u'k': u'10', u'force_dense': u'True'}
# [02/21/2018 15:34:55 INFO 140204977600320] Final configuration: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:34:55 WARNING 140204977600320] Loggers have already been setup.
# [02/21/2018 15:34:55 INFO 140204977600320] Launching parameter server for role scheduler
# [02/21/2018 15:34:55 INFO 140204977600320] {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/1c42f943-1fd6-4e8c-a395-70c2ca4a0337', 'PWD': '/'}
# [02/21/2018 15:34:55 INFO 140204977600320] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/1c42f943-1fd6-4e8c-a395-70c2ca4a0337', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [02/21/2018 15:34:55 INFO 140204977600320] Launching parameter server for role server
# [02/21/2018 15:34:55 INFO 140204977600320] {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/1c42f943-1fd6-4e8c-a395-70c2ca4a0337', 'PWD': '/'}
# [02/21/2018 15:34:55 INFO 140204977600320] envs={'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/1c42f943-1fd6-4e8c-a395-70c2ca4a0337', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [02/21/2018 15:34:55 INFO 140204977600320] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/1c42f943-1fd6-4e8c-a395-70c2ca4a0337', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [02/21/2018 15:34:55 INFO 140204977600320] Using default worker.
# [02/21/2018 15:34:55 INFO 140204977600320] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [02/21/2018 15:34:55 INFO 140204977600320] Create Store: dist_async
# Docker entrypoint called with argument(s): train
# [02/21/2018 15:35:00 INFO 140204977600320] nvidia-smi took: 0.0251789093018 secs to identify 0 gpus
# [02/21/2018 15:35:00 INFO 140204977600320] Number of GPUs being used: 0
# [02/21/2018 15:35:00 INFO 140204977600320] Setting up with params: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:35:00 INFO 140204977600320] Number of GPUs being used: 0
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:170: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:120: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [02/21/2018 15:35:00 INFO 140204977600320] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Max Records Seen Between Resets": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1519227300.307494, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227300.307462}
#
# [02/21/2018 15:35:00 INFO 140204977600320] Iter 10: Short term msd 31.438953. Long term msd 32.826171
# [02/21/2018 15:35:00 INFO 140612828559168] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:35:00 INFO 140612828559168] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'784', u'mini_batch_size': u'500', u'k': u'10', u'force_dense': u'True'}
# [02/21/2018 15:35:00 INFO 140612828559168] Final configuration: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:35:00 WARNING 140612828559168] Loggers have already been setup.
# [02/21/2018 15:35:00 INFO 140612828559168] Environment: {'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/usr/local/nvidia/lib64::/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'ethwe', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.40.0.3', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'aws', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/de6394e7-779d-45cd-8d7b-14beab74fe41', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1'}
# [02/21/2018 15:35:00 INFO 140612828559168] Using default worker.
# [02/21/2018 15:35:00 INFO 140612828559168] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [02/21/2018 15:35:00 INFO 140612828559168] Create Store: dist_async
# [02/21/2018 15:35:00 INFO 140612828559168] nvidia-smi took: 0.0252010822296 secs to identify 0 gpus
# [02/21/2018 15:35:00 INFO 140612828559168] Number of GPUs being used: 0
# [02/21/2018 15:35:00 INFO 140612828559168] Setting up with params: {u'k': u'10', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'init_method': u'random', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'500', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/21/2018 15:35:00 INFO 140612828559168] Number of GPUs being used: 0
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:170: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# /opt/amazon/lib/python2.7/site-packages/ai_algorithms_sdk/config/config_helper.py:120: DeprecationWarning: deprecated
#   warnings.warn("deprecated", DeprecationWarning)
# [02/21/2018 15:35:00 INFO 140612828559168] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Max Records Seen Between Resets": {"count": 1, "max": 500, "sum": 500.0, "min": 500}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1519227300.299773, "Dimensions": {"Host": "algo-2", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227300.299725}
#
# [02/21/2018 15:35:00 INFO 140612828559168] Iter 10: Short term msd 32.266184. Long term msd 34.099832
# [02/21/2018 15:35:00 INFO 140612828559168] Iter 20: Short term msd 29.493689. Long term msd 30.543201
# [02/21/2018 15:35:00 INFO 140612828559168] Iter 30: Short term msd 29.344338. Long term msd 29.783149
# [02/21/2018 15:35:01 INFO 140612828559168] Iter 40: Short term msd 28.838857. Long term msd 29.112906
# [02/21/2018 15:35:00 INFO 140204977600320] Iter 20: Short term msd 29.806709. Long term msd 30.385218
# [02/21/2018 15:35:00 INFO 140204977600320] Iter 30: Short term msd 29.765330. Long term msd 29.919238
# [02/21/2018 15:35:01 INFO 140204977600320] Iter 40: Short term msd 28.975301. Long term msd 29.239804
# [02/21/2018 15:35:01 INFO 140204977600320] processed a total of 25000 examples
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 25500, "sum": 25500.0, "min": 25500}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1519227301.252728, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1519227301.252652}
#
# [02/21/2018 15:35:01 INFO 140204977600320] shrinking 100 centers into 10
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #0. Current mean square distance 11.715877
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #1. Current mean square distance 11.578351
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #2. Current mean square distance 11.618858
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #3. Current mean square distance 11.774046
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #4. Current mean square distance 11.658957
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #5. Current mean square distance 11.117177
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #6. Current mean square distance 11.535639
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #7. Current mean square distance 11.642379
# [02/21/2018 15:35:01 INFO 140612828559168] processed a total of 25000 examples
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Batches Since Last Reset": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 25500, "sum": 25500.0, "min": 25500}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1519227301.168481, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1519227301.168434}
#
# [02/21/2018 15:35:01 INFO 140612828559168] shrinking 100 centers into 10
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #0. Current mean square distance 11.526416
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #1. Current mean square distance 11.526103
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #2. Current mean square distance 11.934375
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #3. Current mean square distance 11.443850
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #4. Current mean square distance 11.328175
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #5. Current mean square distance 11.679529
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #6. Current mean square distance 11.611490
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #7. Current mean square distance 12.080664
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #8. Current mean square distance 11.390031
# [02/21/2018 15:35:01 INFO 140612828559168] local kmeans attempt #9. Current mean square distance 11.519276
# [02/21/2018 15:35:01 INFO 140612828559168] finished shrinking process. Mean Square Distance = 11
# [02/21/2018 15:35:01 INFO 140612828559168] compute all data-center distances: point norm took: 28.7841%, (0.249032 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] collect from kv store took: 23.2085%, (0.200793 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] batch data loading with context took: 20.1119%, (0.174002 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] predict compute msd took: 6.9819%, (0.060405 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] compute all data-center distances: center norm took: 6.1755%, (0.053429 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] gradient: cluster size  took: 4.0118%, (0.034709 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] compute all data-center distances: inner product took: 3.8925%, (0.033677 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] gradient: cluster center took: 3.6578%, (0.031646 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] update state and report convergance took: 1.1651%, (0.010080 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] splitting centers key-value pair took: 1.0411%, (0.009007 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] gradient: one_hot took: 0.8220%, (0.007112 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] predict minus dist took: 0.1197%, (0.001036 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] update set-up time took: 0.0280%, (0.000242 secs)
# [02/21/2018 15:35:01 INFO 140612828559168] TOTAL took: 0.865170001984
# [02/21/2018 15:35:01 INFO 140612828559168] Number of GPUs being used: 0
# [02/21/2018 15:35:01 INFO 140612828559168] No model is serialized on a non-master node
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 315.6759738922119, "sum": 315.6759738922119, "min": 315.6759738922119}, "initialize.time": {"count": 1, "max": 16.206979751586914, "sum": 16.206979751586914, "min": 16.206979751586914}, "model.serialize.time": {"count": 1, "max": 0.22602081298828125, "sum": 0.22602081298828125, "min": 0.22602081298828125}, "update.time": {"count": 1, "max": 868.4108257293701, "sum": 868.4108257293701, "min": 868.4108257293701}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.48804283142089844, "sum": 0.48804283142089844, "min": 0.48804283142089844}, "_shrink.time": {"count": 1, "max": 312.8340244293213, "sum": 312.8340244293213, "min": 312.8340244293213}}, "EndTime": 1519227301.561752, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227300.266354}
#
# [02/21/2018 15:35:01 INFO 140612828559168] Test data was not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1372.262954711914, "sum": 1372.262954711914, "min": 1372.262954711914}, "setuptime": {"count": 1, "max": 20.925045013427734, "sum": 20.925045013427734, "min": 20.925045013427734}}, "EndTime": 1519227301.563692, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227301.561836}
#
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #8. Current mean square distance 11.741054
# [02/21/2018 15:35:01 INFO 140204977600320] local kmeans attempt #9. Current mean square distance 11.331011
# [02/21/2018 15:35:01 INFO 140204977600320] finished shrinking process. Mean Square Distance = 11
# [02/21/2018 15:35:01 INFO 140204977600320] compute all data-center distances: point norm took: 32.5900%, (0.306463 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] batch data loading with context took: 23.5092%, (0.221071 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] collect from kv store took: 12.7908%, (0.120280 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] predict compute msd took: 7.6118%, (0.071578 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] compute all data-center distances: center norm took: 6.8734%, (0.064634 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] gradient: cluster center took: 4.6134%, (0.043382 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] gradient: cluster size  took: 4.2983%, (0.040419 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] compute all data-center distances: inner product took: 3.6841%, (0.034644 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] update state and report convergance took: 1.8813%, (0.017691 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] splitting centers key-value pair took: 1.2260%, (0.011528 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] gradient: one_hot took: 0.7335%, (0.006897 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] predict minus dist took: 0.1667%, (0.001568 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] update set-up time took: 0.0216%, (0.000203 secs)
# [02/21/2018 15:35:01 INFO 140204977600320] TOTAL took: 0.940359115601
# [02/21/2018 15:35:01 INFO 140204977600320] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 406.4650535583496, "sum": 406.4650535583496, "min": 406.4650535583496}, "initialize.time": {"count": 1, "max": 19.068002700805664, "sum": 19.068002700805664, "min": 19.068002700805664}, "model.serialize.time": {"count": 1, "max": 0.35500526428222656, "sum": 0.35500526428222656, "min": 0.35500526428222656}, "update.time": {"count": 1, "max": 944.9150562286377, "sum": 944.9150562286377, "min": 944.9150562286377}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 0.5099773406982422, "sum": 0.5099773406982422, "min": 0.5099773406982422}, "_shrink.time": {"count": 1, "max": 404.29091453552246, "sum": 404.29091453552246, "min": 404.29091453552246}}, "EndTime": 1519227301.660605, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227300.273955}
#
# [02/21/2018 15:35:01 INFO 140204977600320] Test data was not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 5999.253988265991, "sum": 5999.253988265991, "min": 5999.253988265991}, "setuptime": {"count": 1, "max": 28.939008712768555, "sum": 28.939008712768555, "min": 28.939008712768555}}, "EndTime": 1519227301.663151, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1519227301.660718}
# ===== Job Complete =====
# CPU times: user 20.3 s, sys: 692 ms, total: 21 s
# Wall time: 8min 3s

# %%
# %%time

kmeans_predictor = kmeans.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: kmeans-2018-02-21-15-38-16-192
# INFO:sagemaker:Creating endpoint with name kmeans-2018-02-21-15-29-13-264
# -----------------------------------------------------------------------------------------------------------------------------!CPU times: user 516 ms, sys: 60 ms, total: 576 ms
# Wall time: 10min 38s

# %%
result = kmeans_predictor.predict(train_set[0][30:31])
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 5.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 7.347010135650635
#     }
#   }
# }
# ]

# %%
# %%time 

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 24 ms, sys: 0 ns, total: 24 ms
# Wall time: 250 ms

# %%
for cluster in range(10):
    print('\n\n\nCluster {}:'.format(int(cluster)))
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ]
    height=((len(digits)-1)//5)+1
    width=5
    plt.rcParams["figure.figsize"] = (width,height)
    _, subplots = plt.subplots(height, width)
    subplots=numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits):]:
        subplot.axis('off')

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:
